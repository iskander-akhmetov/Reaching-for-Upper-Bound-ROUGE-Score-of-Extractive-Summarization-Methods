# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

from tqdm.notebook import tqdm
from collections import Counter
from matplotlib import pyplot as plt

import os
import traceback
import time
import random

# %%
#saving routines
import pickle
def save_obj(obj, name):
    pickle.dump(obj,open(name + '.pkl', 'wb'), protocol=4)
    
def load_obj(name):
    with open(name + '.pkl', 'rb') as f:
        return pickle.load(f)

#quickly plot any data in 2D
from sklearn.decomposition import PCA

def show_data(data, c=None):
    pca = PCA(n_components=2, whiten=True)
    data_2D = pca.fit_transform(data)
    plt.scatter(data_2D[:, 0], data_2D[:, 1], c=c)
    plt.show()

# %%
#Parallelizing routines

# I mostly borrow this code from http://blog.adeel.io/2016/11/06/parallelize-pandas-map-or-apply/
# https://github.com/rafaelvalero/ParallelTextProcessing/blob/master/parallelizing_text_processing.ipynb
import multiprocessing
import pandas as pd
import numpy as np
from multiprocessing import Pool
import scipy.sparse as sp
#num_partitions = 5
num_cores = multiprocessing.cpu_count()
num_partitions = num_cores-5 # I like to leave some cores for other
#processes
print(num_partitions)



def parallelize_data_cr(df, func):
    parts=[]
    a = np.array_split(df, num_partitions)
    #print(1)
    #del df
    pool = Pool(num_partitions)
    jobs = []
    #print(2)
    #x = pd.concat(pool.map(func, [a,b,c,d,e]))
    finished = [7, 10, 11, 19]
    for i in range(0, num_partitions):
        if i not in finished:
            jobs.append(pool.apply_async(func,(a[i],i)))
    #print(3)
    #x = sp.vstack(pool.map(func, [a,b,c,d,e,f]), format='csr')
    
    for job in jobs:
        parts.append(job.get())
    print(4)
    
    pool.close()
    
    pool.join()
    return parts
# Out:
# 27

# %%
#Evaluate with ROUGE

from rouge import Rouge 

hypothesis = "the #### transcript is a written version of each day 's cnn student news program use this transcript to he    lp students with reading comprehension and vocabulary use the weekly newsquiz to test your knowledge of storie s you     saw on cnn student news"
reference = "this page includes the show transcript use the transcript to help students with reading comprehension and     vocabulary at the bottom of the page , comment for a chance to be mentioned on cnn student news . you must be a teac    her or a student age # # or older to request a mention on the cnn student news roll call . the weekly newsquiz tests     students ' knowledge of even ts in the news"

#rouge metric based on https://pypi.org/project/rouge/
def my_rouge2(hypothesis, reference):
    rouge = Rouge()
    scores = rouge.get_scores(hypothesis, reference)
    
    #rouge-1
    r1_f1=scores[0]['rouge-1']['f']
    r1_precision=scores[0]['rouge-1']['p']
    r1_recall=scores[0]['rouge-1']['r']
    
    #rouge-2
    r2_f1=scores[0]['rouge-2']['f']
    r2_precision=scores[0]['rouge-2']['p']
    r2_recall=scores[0]['rouge-2']['r']
    
    return r1_f1, r2_f1, #, precision, recall

my_rouge2(hypothesis, reference)
# Out:
# (0.4786324739396596, 0.2608695605353498)

# %% [markdown]
# # Load data

# %%
ds = load_obj('ds_merged')
ds.head()
# Out:
#         article_id                                       article_text  \
# 0  astro-ph0202198  [the study of supernovae ( sne ) has greatly a...
# 1        0905.2691  [it is believed that solar magnetic fields are...
# 2        1305.7010  [the origin - destination ( od ) matrix is imp...
# 3        1402.0371  [multiscale dynamics is present in many phenom...
# 4       1701.00774  [the @xmath3-transformation has been extensive...
#
#                                        abstract_text  \
# 0  [large numbers of supernovae ( sne ) have been...
# 1  [we investigate the emergence of magnetic flux...
# 2  [the estimation of the number of passengers wi...
# 3  [the classical structure - function ( sf ) met...
# 4  [given a real number @xmath0 , we study the as...
#
#                                        section_names  \
# 0  [introduction, method, results, future prospec...
# 1  [introduction, observations and data reduction...
# 2  [introduction, the passenger model, the observ...
# 3  [introduction, detrending analysis and detrend...
# 4  [introduction, coded negative beta-shift, lap ...
#
#                                             sections  len_text  len_abstract  \
# 0  [[the study of supernovae ( sne ) has greatly ...       341            12
# 1  [[it is believed that solar magnetic fields ar...       329            11
# 2  [[the origin - destination ( od ) matrix is im...       225            10
# 3  [[multiscale dynamics is present in many pheno...       216            15
# 4  [[the @xmath3-transformation has been extensiv...       353            11
#
#    sent_ext  word_ext  word_inf  ...  voted_method  voted_r1  voted_r2  \
# 0  0.000000  0.897436  0.076004  ...           vns  0.541667  0.167247
# 1  0.000000  0.884892  0.073258  ...           wih  0.629482  0.296000
# 2  0.000000  0.740157  0.074367  ...           vns  0.502901  0.128155
# 3  0.066667  0.949045  0.171659  ...           wih  0.767442  0.556667
# 4  0.000000  0.867925  0.059547  ...           wih  0.541176  0.236407
#
#                           best_summary_vns_initgreed  \
# 0  [once discovered , the study of a particular s...
# 1  [they move upward and emerge into the solar at...
# 2  [a particular application of the od matrix est...
# 3  [a detrended structure - function ( dsf ) meth...
# 4  [thus , the previous proposition allows us to ...
#
#    best_rouge1_vns_initgreed  best_rouge2_vns_initgreed len_sum_vns  \
# 0                   0.484935                   0.146763          15
# 1                   0.629482                   0.296000          14
# 2                   0.474187                   0.119002          19
# 3                   0.767442                   0.563333          16
# 4                   0.541176                   0.236407          14
#
#   len_sum_wih  len_sum_vot  len_sum_vns_init_greed
# 0           5           15                       5
# 1           9            9                       9
# 2           4           19                      14
# 3          11           11                      11
# 4           4            4                       4
#
# [5 rows x 27 columns]

# %% [markdown]
# # Calculating best possible rouge summary

# %%
import random

def crossover(cand1, cand2, n_chromosomes):
    genetic_pool = cand1 + cand2
    random.shuffle(genetic_pool)
    offspring = random.sample(genetic_pool, n_chromosomes)
    return offspring
    

def genetic_best_sum(text, abstract, generations):
    d=len(text)
    a=len(abstract)
    g_sum='. '.join(abstract)

    #shuffle text sentences
    random.shuffle(text)

    #generate candidates    
    candidates = [text[i:i+a] for i in range(0, len(text), a)]
    n_offspr = len(candidates) // 2

    for g in range(generations):
        #print(g)
        #crossover all with all
        offsprings = []
        for i in range(len(candidates)):
            #print(i)
            for j in range(i+1, len(candidates)):
                #print(j)
                offsprings.append(crossover(candidates[i], candidates[j], a))

        #evaluate offsprings
        offspring_eval = [my_rouge2(' '.join(ofspr), g_sum)[0] for ofspr in offsprings]
        best_idx = np.array(offspring_eval).argsort()[-n_offspr:]
        candidates = [list(c) for c in np.array(offsprings)[best_idx]]
        #print(candidates)
        #print('Average offspring ROUGE1={} for generation {}'.format(np.array(offspring_eval)[best_idx].mean(), g))
        
    best_summary = offsprings[best_idx[-1]]
    #print(offspring_eval[best_idx[-1]])
    best_rouge = my_rouge2(' '.join(best_summary), g_sum)
    #print(best_rouge)
    return best_summary, best_rouge

# %%
text = ds.article_text.values[0]
abstract = ds.abstract_text.values[0] 
#init_sol = ds.best_summary_wih.values[0]

genetic_best_sum(text, abstract, 8)
# Out:
# Average offspring ROUGE1=0.4562242609900288 for generation 0
# Average offspring ROUGE1=0.4867342758034003 for generation 1
# Average offspring ROUGE1=0.5045207898394679 for generation 2
# Average offspring ROUGE1=0.5221140531470002 for generation 3
# Average offspring ROUGE1=0.5307359262835323 for generation 4
# Average offspring ROUGE1=0.5378869005033071 for generation 5
# Average offspring ROUGE1=0.5455432687873658 for generation 6
# Average offspring ROUGE1=0.5552315332747049 for generation 7
# 0.5848142114924014
# (0.5848142114924014, 0.1750405136528769)
# (['thus , only one color ( @xmath2 ) remains in the johnson - cousins system .',
#   '.    however , the center of the diagram is populated by sne of all types . for example , a zero - redshift sn , of unknown type , with colors of @xmath43 mag , @xmath44 mag , would be impossible to classify based on these colors only .',
#   'we are aware that a large population of intrinsically faint sne ( e.g. , sn 1987a - like ) may be underrepresented in current sn statistics .',
#   'the core of our classification algorithm is the spectral database : a compilation of optical spectra of nearby sne .',
#   'finally , we have demonstrated the application of our method to a recently discovered sn from the sdss , and we have shown how this technique may become a valuable tool for the analysis of the large sn samples expected to emerge from this and other programs that are already active or will begin soon .',
#   'we therefore concentrate our efforts on using multi - color broadband photometry to classify sne .',
#   'in addition , a few complementary spectra of other events were included in order to verify consistency and fill gaps in the temporal evolution , when needed .',
#   'it is therefore likely that analysis based on our database will be relevant to the large majority of sne discovered by current programs .',
#   'sne are heterogeneous events , empirically classified into many subtypes , with the main classification criteria based on spectral properties .',
#   'as we move even farther up the redshift scale the use of infrared ( ir ) filters is required . between @xmath73 and @xmath74 ,',
#   'one can see that the unique colors of young ( @xmath40  d ) and very old ( @xmath31  d ) sne  ia can not be masked even by significant reddening in their host .',
#   'perlmutter et al . 2000 ; automated sn detections in sloan digital sky survey ( sdss ) data  vanden berk et al .'],
#  (0.5848142114924014, 0.1750405136528769))

# %%
r_of_generation = [genetic_best_sum(text, abstract, i+1)[1][0] for i in tqdm(range(10))]
plt.plot(r_of_generation)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Average offspring ROUGE1=0.4653508340124972 for generation 0
# 0.4754990875791582
# (0.4754990875791582, 0.12021857425529463)
# Average offspring ROUGE1=0.46584569177206786 for generation 0
# Average offspring ROUGE1=0.4957182384645757 for generation 1
# 0.5204991037443324
# (0.5204991037443324, 0.11449015601178972)
# Average offspring ROUGE1=0.467311203349388 for generation 0
# Average offspring ROUGE1=0.49696150418706286 for generation 1
# Average offspring ROUGE1=0.512212984823027 for generation 2
# 0.536115564841071
# (0.536115564841071, 0.15458936699842613)
# Average offspring ROUGE1=0.45410461869748914 for generation 0
# Average offspring ROUGE1=0.48972070829577535 for generation 1
# Average offspring ROUGE1=0.5104548923707631 for generation 2
# Average offspring ROUGE1=0.5210243644828055 for generation 3
# 0.5346534603519807
# (0.5346534603519807, 0.16887416719091283)
# Average offspring ROUGE1=0.4663517179669677 for generation 0
# Average offspring ROUGE1=0.49340649863152447 for generation 1
# Average offspring ROUGE1=0.5094158946393631 for generation 2
# Average offspring ROUGE1=0.5253969640094573 for generation 3
# Average offspring ROUGE1=0.5395158800846531 for generation 4
# 0.5671140889611392
# (0.5671140889611392, 0.16161615661757886)
# Average offspring ROUGE1=0.46554705991200934 for generation 0
# Average offspring ROUGE1=0.490419194353772 for generation 1
# Average offspring ROUGE1=0.5176091386328255 for generation 2
# Average offspring ROUGE1=0.5336574397864812 for generation 3
# Average offspring ROUGE1=0.5433427937430132 for generation 4
# Average offspring ROUGE1=0.5482846664540116 for generation 5
# 0.5616883067001708
# (0.5616883067001708, 0.15635178654288126)
# Average offspring ROUGE1=0.4556010412204036 for generation 0
# Average offspring ROUGE1=0.4833892753312399 for generation 1
# Average offspring ROUGE1=0.5037971985898674 for generation 2
# Average offspring ROUGE1=0.5213155157394829 for generation 3
# Average offspring ROUGE1=0.5277601196208868 for generation 4
# Average offspring ROUGE1=0.5388292300045626 for generation 5
# Average offspring ROUGE1=0.5457237078356961 for generation 6
# 0.5548387046924558
# (0.5548387046924558, 0.16828478465914698)
# Average offspring ROUGE1=0.451213058352173 for generation 0
# Average offspring ROUGE1=0.47917630254708227 for generation 1
# Average offspring ROUGE1=0.4988574083764416 for generation 2
# Average offspring ROUGE1=0.511028115282793 for generation 3
# Average offspring ROUGE1=0.5220891051936157 for generation 4
# Average offspring ROUGE1=0.532120355750921 for generation 5
# Average offspring ROUGE1=0.5382274226153039 for generation 6
# Average offspring ROUGE1=0.5461215720884901 for generation 7
# 0.5583038819320382
# (0.5583038819320382, 0.18794325741763507)
# Average offspring ROUGE1=0.45271516556148905 for generation 0
# Average offspring ROUGE1=0.4870532535541338 for generation 1
# Average offspring ROUGE1=0.5026589628681365 for generation 2
# Average offspring ROUGE1=0.5135288430417976 for generation 3
# Average offspring ROUGE1=0.5303183397264852 for generation 4
# Average offspring ROUGE1=0.5374801473607728 for generation 5
# Average offspring ROUGE1=0.5398558172784801 for generation 6
# Average offspring ROUGE1=0.5445019779274728 for generation 7
# Average offspring ROUGE1=0.5379167797233974 for generation 8
# 0.5463917475775558
# (0.5463917475775558, 0.1586206846554104)
# Average offspring ROUGE1=0.46157730410658676 for generation 0
# Average offspring ROUGE1=0.49631352882376817 for generation 1
# Average offspring ROUGE1=0.5095315371087994 for generation 2
# Average offspring ROUGE1=0.526468562467982 for generation 3
# Average offspring ROUGE1=0.5373452023614648 for generation 4
# Average offspring ROUGE1=0.5476802796713637 for generation 5
# Average offspring ROUGE1=0.5516149665381596 for generation 6
# Average offspring ROUGE1=0.5574537808623262 for generation 7
# Average offspring ROUGE1=0.557669720166236 for generation 8
# Average offspring ROUGE1=0.562600881621709 for generation 9
# 0.5780730847045287
# (0.5780730847045287, 0.15999999500355572)

# %%
r_of_generation2 = [genetic_best_sum(text, abstract, i+10)[1][0] for i in tqdm(range(10))]
plt.plot(r_of_generation + r_of_generation2)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Average offspring ROUGE1=0.46498176677830794 for generation 0
# Average offspring ROUGE1=0.48828658418878323 for generation 1
# Average offspring ROUGE1=0.5103921559298378 for generation 2
# Average offspring ROUGE1=0.5321078170490431 for generation 3
# Average offspring ROUGE1=0.5441910492795853 for generation 4
# Average offspring ROUGE1=0.557139383042783 for generation 5
# Average offspring ROUGE1=0.5621578595820982 for generation 6
# Average offspring ROUGE1=0.5637995639550023 for generation 7
# Average offspring ROUGE1=0.5714862254805685 for generation 8
# Average offspring ROUGE1=0.5748424881229083 for generation 9
# 0.5979729679734866
# (0.5979729679734866, 0.19322033398356808)
# Average offspring ROUGE1=0.46390640835193375 for generation 0
# Average offspring ROUGE1=0.4898790223818473 for generation 1
# Average offspring ROUGE1=0.5067044614643074 for generation 2
# Average offspring ROUGE1=0.5192774967188487 for generation 3
# Average offspring ROUGE1=0.5334351332327805 for generation 4
# Average offspring ROUGE1=0.5443286329049654 for generation 5
# Average offspring ROUGE1=0.5512357231830134 for generation 6
# Average offspring ROUGE1=0.5512400862616433 for generation 7
# Average offspring ROUGE1=0.5555788143456851 for generation 8
# Average offspring ROUGE1=0.5563553239648642 for generation 9
# Average offspring ROUGE1=0.5633275043630669 for generation 10
# 0.5719424410577222
# (0.5719424410577222, 0.16606497696412062)
# Average offspring ROUGE1=0.4642216135267437 for generation 0
# Average offspring ROUGE1=0.4857763031118276 for generation 1
# Average offspring ROUGE1=0.5081911822471139 for generation 2
# Average offspring ROUGE1=0.5228508577255987 for generation 3
# Average offspring ROUGE1=0.5305687043559991 for generation 4
# Average offspring ROUGE1=0.5388056055977423 for generation 5
# Average offspring ROUGE1=0.5415699805794959 for generation 6
# Average offspring ROUGE1=0.5460423146706596 for generation 7
# Average offspring ROUGE1=0.550787123091194 for generation 8
# Average offspring ROUGE1=0.5574641780750228 for generation 9
# Average offspring ROUGE1=0.5553226137774929 for generation 10
# Average offspring ROUGE1=0.5570521645244418 for generation 11
# 0.574912886988248
# (0.574912886988248, 0.17482516982737556)
# Average offspring ROUGE1=0.4550040469050144 for generation 0
# Average offspring ROUGE1=0.4860462607366795 for generation 1
# Average offspring ROUGE1=0.5021838597536451 for generation 2
# Average offspring ROUGE1=0.5218542283161821 for generation 3
# Average offspring ROUGE1=0.5429326469014482 for generation 4
# Average offspring ROUGE1=0.5614051312406263 for generation 5
# Average offspring ROUGE1=0.5653950216585251 for generation 6
# Average offspring ROUGE1=0.567374422533259 for generation 7
# Average offspring ROUGE1=0.5702041708776904 for generation 8
# Average offspring ROUGE1=0.5787770267357848 for generation 9
# Average offspring ROUGE1=0.5815449165668433 for generation 10
# Average offspring ROUGE1=0.5772485924262752 for generation 11
# Average offspring ROUGE1=0.5796527623078271 for generation 12
# 0.6013985964015968
# (0.6013985964015968, 0.19298245114336735)
# Average offspring ROUGE1=0.45097441055393234 for generation 0
# Average offspring ROUGE1=0.4789779456244527 for generation 1
# Average offspring ROUGE1=0.5003236046565487 for generation 2
# Average offspring ROUGE1=0.5203693730411362 for generation 3
# Average offspring ROUGE1=0.538698551099601 for generation 4
# Average offspring ROUGE1=0.5454549723375721 for generation 5
# Average offspring ROUGE1=0.5531675083286052 for generation 6
# Average offspring ROUGE1=0.5587681233942268 for generation 7
# Average offspring ROUGE1=0.5642983810885608 for generation 8
# Average offspring ROUGE1=0.5613875925205613 for generation 9
# Average offspring ROUGE1=0.5668180599891024 for generation 10
# Average offspring ROUGE1=0.57086037118915 for generation 11
# Average offspring ROUGE1=0.5703886207205995 for generation 12
# Average offspring ROUGE1=0.5687163926368853 for generation 13
# 0.5778546662812347
# (0.5778546662812347, 0.14236110611207578)
# Average offspring ROUGE1=0.46107814103615885 for generation 0
# Average offspring ROUGE1=0.4855449130628714 for generation 1
# Average offspring ROUGE1=0.5067685106069796 for generation 2
# Average offspring ROUGE1=0.5237588593322391 for generation 3
# Average offspring ROUGE1=0.5292877080142346 for generation 4
# Average offspring ROUGE1=0.5410137289250289 for generation 5
# Average offspring ROUGE1=0.5452844141877761 for generation 6
# Average offspring ROUGE1=0.5481542648230876 for generation 7
# Average offspring ROUGE1=0.5509747209590258 for generation 8
# Average offspring ROUGE1=0.5489389770315837 for generation 9
# Average offspring ROUGE1=0.5505788055490879 for generation 10
# Average offspring ROUGE1=0.5519638970061239 for generation 11
# Average offspring ROUGE1=0.5548322366090201 for generation 12
# Average offspring ROUGE1=0.5497884093196451 for generation 13
# Average offspring ROUGE1=0.556131126875823 for generation 14
# 0.5651438190274308
# (0.5651438190274308, 0.16977928192735536)
# Average offspring ROUGE1=0.45091966551759954 for generation 0
# Average offspring ROUGE1=0.48415940899094795 for generation 1
# Average offspring ROUGE1=0.5104331839645855 for generation 2
# Average offspring ROUGE1=0.5175604536209805 for generation 3
# Average offspring ROUGE1=0.5270101120835536 for generation 4
# Average offspring ROUGE1=0.5352717989458265 for generation 5
# Average offspring ROUGE1=0.5439171155804623 for generation 6
# Average offspring ROUGE1=0.5491773426584442 for generation 7
# Average offspring ROUGE1=0.5504925954650617 for generation 8
# Average offspring ROUGE1=0.5612659955490256 for generation 9
# Average offspring ROUGE1=0.5592398251314967 for generation 10
# Average offspring ROUGE1=0.555570494506732 for generation 11
# Average offspring ROUGE1=0.5574935945536482 for generation 12
# Average offspring ROUGE1=0.5552234026735411 for generation 13
# Average offspring ROUGE1=0.5540721942511675 for generation 14
# Average offspring ROUGE1=0.553802439262646 for generation 15
# 0.5676126828153769
# (0.5676126828153769, 0.17755443386334255)
# Average offspring ROUGE1=0.4627471236772857 for generation 0
# Average offspring ROUGE1=0.48485297689016116 for generation 1
# Average offspring ROUGE1=0.5111763281216656 for generation 2
# Average offspring ROUGE1=0.5327194469396652 for generation 3
# Average offspring ROUGE1=0.5378599256447807 for generation 4
# Average offspring ROUGE1=0.5477924620929076 for generation 5
# Average offspring ROUGE1=0.5540847482430772 for generation 6
# Average offspring ROUGE1=0.5640556036471884 for generation 7
# Average offspring ROUGE1=0.5667802767566897 for generation 8
# Average offspring ROUGE1=0.5707166023883905 for generation 9
# Average offspring ROUGE1=0.5668693523490369 for generation 10
# Average offspring ROUGE1=0.5671921374171244 for generation 11
# Average offspring ROUGE1=0.5686813579774977 for generation 12
# Average offspring ROUGE1=0.5747199275334041 for generation 13
# Average offspring ROUGE1=0.5738401336893435 for generation 14
# Average offspring ROUGE1=0.5798439962953704 for generation 15
# Average offspring ROUGE1=0.575402477805618 for generation 16
# 0.5896980411895171
# (0.5896980411895171, 0.18538323921517802)
# Average offspring ROUGE1=0.46412631284378036 for generation 0
# Average offspring ROUGE1=0.48798925066748533 for generation 1
# Average offspring ROUGE1=0.5135622063385473 for generation 2
# Average offspring ROUGE1=0.5280065842608483 for generation 3
# Average offspring ROUGE1=0.5344507867578543 for generation 4
# Average offspring ROUGE1=0.5402009327187861 for generation 5
# Average offspring ROUGE1=0.545710979626782 for generation 6
# Average offspring ROUGE1=0.5527169230315777 for generation 7
# Average offspring ROUGE1=0.5643037456356629 for generation 8
# Average offspring ROUGE1=0.5605412207985616 for generation 9
# Average offspring ROUGE1=0.571228476536315 for generation 10
# Average offspring ROUGE1=0.5675804645513308 for generation 11
# Average offspring ROUGE1=0.5711205493767231 for generation 12
# Average offspring ROUGE1=0.5705392403801282 for generation 13
# Average offspring ROUGE1=0.5699814006128875 for generation 14
# Average offspring ROUGE1=0.5734747285110787 for generation 15
# Average offspring ROUGE1=0.5769657546873187 for generation 16
# Average offspring ROUGE1=0.5707870588103428 for generation 17
# 0.588235289118605
# (0.588235289118605, 0.17013888388985354)
# Average offspring ROUGE1=0.45655603520505955 for generation 0
# Average offspring ROUGE1=0.48301128760381673 for generation 1
# Average offspring ROUGE1=0.5048745890843359 for generation 2
# Average offspring ROUGE1=0.519082623968769 for generation 3
# Average offspring ROUGE1=0.5283245720076382 for generation 4
# Average offspring ROUGE1=0.5366915555274389 for generation 5
# Average offspring ROUGE1=0.5442516979936763 for generation 6
# Average offspring ROUGE1=0.5460527799300762 for generation 7
# Average offspring ROUGE1=0.5538217095142731 for generation 8
# Average offspring ROUGE1=0.5605564131284934 for generation 9
# Average offspring ROUGE1=0.5588060342021557 for generation 10
# Average offspring ROUGE1=0.5640808610810014 for generation 11
# Average offspring ROUGE1=0.5651980852365964 for generation 12
# Average offspring ROUGE1=0.5689428342452381 for generation 13
# Average offspring ROUGE1=0.5650629300336891 for generation 14
# Average offspring ROUGE1=0.5672833183612916 for generation 15
# Average offspring ROUGE1=0.564897468369661 for generation 16
# Average offspring ROUGE1=0.5657242903619353 for generation 17
# Average offspring ROUGE1=0.5652348773478572 for generation 18
# 0.5773195826291021
# (0.5773195826291021, 0.17241378810368624)

# %%
random.shuffle(text)

# %%
import os.path
#prepare the data for classification

def create_classif_data(texts, abstracts, ids, init_sol, c):
    if os.path.isfile('./_gen_tmp/best_rouges_gen'+str(c)+'.pkl'):
        #X_sent=load_obj('./_gen_tmp/X_vns'+str(c))
        Art_ID=load_obj('./_gen_tmp/Art_ID_gen'+str(c))
        #Y=load_obj('./_gen_tmp/Y_vns'+str(c))
        best_rouges=load_obj('./_gen_tmp/best_rouges_gen'+str(c))
        best_sum=load_obj('./_gen_tmp/best_sum_gen'+str(c))
        start=len(best_rouges)
        print('Process restarting. Starting from',start)
    else:
        X_sent = []
        #Y = []
        Art_ID = []
        best_rouges = []
        best_sum = []
        start=0
    #art_num=100
    cnt_save=0
    
    for t, a, a_ids, insol in zip(tqdm(texts[start:]), abstracts[start:], ids[start:], init_sol[start:]):
        #print(len(t), len(a))
        if len(t)>len(a) and len(a)>=5:
            try:
                #print(1)
                s, r = genetic_best_sum(t, a, 6)
                #X_sent.append(t)
                Art_ID.append([a_ids for i in range(len(t))])
                #Y.append(issumsent)
                best_rouges.append(r)
                best_sum.append(s)

                
                cnt_save+=1
                
                #save results on the go
                if cnt_save%50==0:
                    print('Saving work', c, 'counter value', cnt_save)
                    #save_obj(X_sent, './_gen_tmp/X_gen'+str(c))
                    #save_obj(Y, './_gen_tmp/Y_vns'+str(c))
                    save_obj(Art_ID, './_gen_tmp/Art_ID_gen'+str(c))
                    save_obj(best_rouges, './_gen_tmp/best_rouges_gen'+str(c))
                    save_obj(best_sum, './_gen_tmp/best_sum_gen'+str(c))
            except Exception as err:
                #print('Err')
                traceback.print_exc()
                continue
        else:
            print('Number of sentences in article are smaller than in abstract OR abstract is shorter than 5 sentences')
    
    #final save
    #save_obj(X_sent, './_gen_tmp/X_vns'+str(c))
    #save_obj(Y, './_gen_tmp/Y_vns'+str(c))
    save_obj(Art_ID, './_gen_tmp/Art_ID_gen'+str(c))
    save_obj(best_rouges, './_gen_tmp/best_rouges_gen'+str(c))
    save_obj(best_sum, './_gen_tmp/best_sum_gen'+str(c))
            
       
    return Art_ID, best_rouges, best_sum #X_sent, Y,

# %%
create_classif_data(ds.article_text[0:3], ds.abstract_text[0:3], ds.article_id[0:3], ds.best_summary_wih.values[0:3], 150)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# ([['astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198',
#    'astro-ph0202198'],
#   ['0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691',
#    '0905.2691'],
#   ['1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010',
#    '1305.7010']],
#  [(0.5617283901075008, 0.15479875665596352),
#   (0.5818965467245095, 0.19480518980556974),
#   (0.5010438363397998, 0.0838574373517225)],
#  [['faint , high-@xmath12 sne are usually observed at optical wavelengths ( i.e. , @xmath62 , @xmath65 , or @xmath66 bands ) . in order to use these bands for classification , knowledge of the restframe uv spectrum',
#    'once discovered , the study of a particular sn , and its use as a tool for any of the applications above , is almost always based on spectroscopic verification and classification .',
#    'all spectra were de - redshifted according to the host - galaxy redshift taken from the ned database .',
#    'as already mentioned in @xmath97 , work along these lines has been presented by dg2002 , who replace missing observational data with rough estimates or models .',
#    'since we want to constrain the type of a sn with an arbitrary ( but known ) redshift , it is not simple to utilize broadband photometry ; k - corrections for sne of all types , and at all ages , are currently unknown . instead , we have compiled a large spectral database of nearby , well - observed sne .',
#    'our sn classification method is based on colors , determined by the spectral energy distribution ( sed ) of each event . by definition',
#    'we have shown that the type of a sn may be uniquely determined in some cases . even when this is not the case , constraints on the type may still be drawn .',
#    'one can see that the unique colors of young ( @xmath40  d ) and very old ( @xmath31  d ) sne  ia can not be masked even by significant reddening in their host .',
#    'however , the tools developed in this paper may enable one to detect sne by their colors alone .',
#    'finally , we have demonstrated the application of our method to a recently discovered sn from the sdss , and we have shown how this technique may become a valuable tool for the analysis of the large sn samples expected to emerge from this and other programs that are already active or will begin soon .',
#    '2001 ) : sne  ic are red compared to sne  ia at a similar redshift .',
#    'classification is obviously more difficult .'],
#   ['however , magnetic fields can be detected through brightness enhancements in the h filtergrams .',
#    'thus , a fraction of the loops are able to reach the low chromosphere , carrying magnetic flux with them .',
#    'some of them also produce  h brightness enhancements . in this context',
#    'about 77% of the loops that appear in the solar surface never rise to the chromosphere .',
#    'the reconstructed images cover a fov of @xmath21 and have a spatial resolution of about 0.2 .',
#    'the rate at which magnetic flux is carried to the quiet photosphere by the loops can be estimated to be @xmath151  mx  s@xmath3  arcsec@xmath1 , or @xmath152  mx over the solar surface per day .',
#    'figure [ primer_ejemplo ] shows the first stages of the emergence of a small - scale magnetic loop as seen in the 630.25  nm line .',
#    '@xcite and @xcite demonstrated that the emergence of magnetic flux on granular scales brings large amounts of horizontal fields to the photosphere both in plage regions and in the quiet sun .',
#    'an important result is that 23% of the loops are detected in the b magnetograms after their appearance in the photosphere ( 16 cases out of 69 ) .',
#    'thus , a fraction of the loops are able to reach the low chromosphere , carrying magnetic flux with them .',
#    'the exposure times were 0.1 s and 0.3 s , respectively .'],
#   ['let call @xmath12 the matrix of zone passengers numbers .',
#    'let m be a @xmath122 matrix , representing departure and arrival stations ( origin and destination ) .',
#    'we use the information available from surveys to infer the correct projection matrix and reduce significantly the size of the parameter space . by using a maximum likelihood approach ,',
#    'all these papers _ are not passengers oriented_. + most of the work relating to od matrix estimation are based on passengers observations assuming the knowledge of where the people get in and out of the public transport .',
#    'we list in the subsections [ om - casual],[om - deparr ] and [ om - regular ] the different kind of observations .',
#    'we use survey data collection from public transport users , and estimate the approximate whole matrix structure through the estimation of its eigenvectors .',
#    'for instance , we can observe that the log(mse ) profile is identical in fig .',
#    '@xmath109 is symmetric , and roughly correspond to an equal partition of the passengers in the different stations .',
#    'for instance , we can observe that the log(mse ) profile is identical in fig .',
#    'most of the papers in the literature solve this problem by postulating a general model for the trip distribution , for example a gravity type model @xcite , which aims at introducing a prior knowledge on the traffic flows and assigning a cost to each journey .']])

# %% [markdown]
# ## Parallelize

# %%
def create_data(data,c):
    print("Process working on: "+str(c))
    #lem_text=[custom_lemm(t) for t in tqdm(data)]
    idx, best_rouges, best_sum = create_classif_data(data.article_text, 
                                                           data.abstract_text, 
                                                           data.article_id, 
                                                           data.best_summary_wih, 
                                                           c)
    print("Process #%s finished" % c)
    return idx, best_rouges, best_sum

# %%
def parallelize_data_cr(df, func):
    parts=[]
    a = np.array_split(df, num_partitions)
    #print(1)
    #del df
    pool = Pool(num_partitions)
    jobs = []
    #print(2)
    #x = pd.concat(pool.map(func, [a,b,c,d,e]))
    finished=[]
    for i in range(0, num_partitions):
        if i not in finished:
            jobs.append(pool.apply_async(func,(a[i],i)))
    #print(3)
    #x = sp.vstack(pool.map(func, [a,b,c,d,e,f]), format='csr')
    
    for job in jobs:
        parts.append(job.get())
    print(4)
    
    pool.close()
    
    pool.join()
    return parts

# %%
classif_data=parallelize_data_cr(ds, create_data)
# Out:
# Process working on: 0
#   0%|          | 0/632 [00:00<?, ?it/s]
# Process working on: 1
#   0%|          | 0/632 [00:00<?, ?it/s]
# Process working on: 2
#   0%|          | 0/631 [00:00<?, ?it/s]
# Process working on: 3
#   0%|          | 0/631 [00:00<?, ?it/s]
# Process working on: 4
#   0%|          | 0/631 [00:00<?, ?it/s]
# Process working on: 5
#   0%|          | 0/631 [00:00<?, ?it/s]
# Process working on: 6
#   0%|          | 0/631 [00:00<?, ?it/s]
# Process working on: 7
#   0%|          | 0/631 [00:00<?, ?it/s]
# Process working on: 8
#   0%|          | 0/631 [00:00<?, ?it/s]
# Process working on: 9
#   0%|          | 0/631 [00:00<?, ?it/s]
# Process working on: 10
#   0%|          | 0/631 [00:00<?, ?it/s]
# Process working on: 11
#   0%|          | 0/631 [00:00<?, ?it/s]
# Process working on: 12
#   0%|          | 0/631 [00:00<?, ?it/s]
# Process working on: 13
#   0%|          | 0/631 [00:00<?, ?it/s]
# Process working on: 14
#   0%|          | 0/631 [00:00<?, ?it/s]
# Process working on: 15
#   0%|          | 0/631 [00:00<?, ?it/s]
# Process working on: 16
#   0%|          | 0/631 [00:00<?, ?it/s]
# Process working on: 17
#   0%|          | 0/631 [00:00<?, ?it/s]
# Process working on: 18
#   0%|          | 0/631 [00:00<?, ?it/s]
# Process working on: 19
#   0%|          | 0/631 [00:00<?, ?it/s]
# Process working on: 20
#   0%|          | 0/631 [00:00<?, ?it/s]
# Process working on: 21
#   0%|          | 0/631 [00:00<?, ?it/s]
# Process working on: 22
#   0%|          | 0/631 [00:00<?, ?it/s]
# Process working on: 23
#   0%|          | 0/631 [00:00<?, ?it/s]
# Process working on: 24
#   0%|          | 0/631 [00:00<?, ?it/s]
# Process working on: 25
#   0%|          | 0/631 [00:00<?, ?it/s]
# Process working on: 26
#   0%|          | 0/631 [00:00<?, ?it/s]
# Saving work 8 counter value 50
# Saving work 13 counter value 50
# Saving work 16 counter value 50
# Saving work 22 counter value 50
# Saving work 11 counter value 50
# Saving work 12 counter value 50
# Saving work 24 counter value 50
# Saving work 18 counter value 50
# Saving work 3 counter value 50
# Saving work 21 counter value 50
# Saving work 9 counter value 50
# Saving work 23 counter value 50
# Saving work 6 counter value 50
# Saving work 1 counter value 50
# Saving work 10 counter value 50
# Saving work 0 counter value 50
# Saving work 17 counter value 50
# Saving work 4 counter value 50
# Saving work 7 counter value 50
# Saving work 2 counter value 50
# Saving work 20 counter value 50
# Saving work 25 counter value 50
# Saving work 15 counter value 50
# Saving work 5 counter value 50
# Saving work 19 counter value 50
# Saving work 14 counter value 50
# Saving work 26 counter value 50
# Saving work 13 counter value 100
# Saving work 22 counter value 100
# Saving work 16 counter value 100
# Saving work 24 counter value 100
# Saving work 1 counter value 100
# Saving work 5 counter value 100
# Saving work 11 counter value 100
# Saving work 9 counter value 100
# Saving work 21 counter value 100
# Saving work 8 counter value 100
# Saving work 2 counter value 100
# Saving work 15 counter value 100
# Saving work 23 counter value 100
# Saving work 18 counter value 100
# Saving work 3 counter value 100
# Saving work 12 counter value 100
# Saving work 17 counter value 100
# Saving work 4 counter value 100
# Saving work 6 counter value 100
# Saving work 14 counter value 100
# Saving work 19 counter value 100
# Saving work 20 counter value 100
# Saving work 25 counter value 100
# Saving work 0 counter value 100
# Saving work 10 counter value 100
# Saving work 7 counter value 100
# Saving work 26 counter value 100
# Saving work 22 counter value 150
# Saving work 24 counter value 150
# Saving work 13 counter value 150
# Saving work 16 counter value 150
# Saving work 9 counter value 150
# Saving work 23 counter value 150
# Saving work 8 counter value 150
# Saving work 4 counter value 150
# Saving work 1 counter value 150
# Saving work 11 counter value 150
# Saving work 17 counter value 150
# Saving work 15 counter value 150
# Saving work 19 counter value 150
# Saving work 20 counter value 150
# Saving work 18 counter value 150
# Saving work 5 counter value 150
# Saving work 12 counter value 150
# Saving work 10 counter value 150
# Saving work 21 counter value 150
# Saving work 2 counter value 150
# Saving work 0 counter value 150
# Saving work 14 counter value 150
# Saving work 6 counter value 150
# Saving work 7 counter value 150
# Saving work 3 counter value 150
# Saving work 25 counter value 150
# Saving work 16 counter value 200
# Saving work 22 counter value 200
# Saving work 13 counter value 200
# Saving work 1 counter value 200
# Saving work 26 counter value 150
# Saving work 24 counter value 200
# Saving work 4 counter value 200
# Saving work 23 counter value 200
# Saving work 11 counter value 200
# Saving work 9 counter value 200
# Saving work 8 counter value 200
# Saving work 21 counter value 200
# Saving work 17 counter value 200
# Saving work 2 counter value 200
# Saving work 12 counter value 200
# Saving work 20 counter value 200
# Saving work 10 counter value 200
# Saving work 5 counter value 200
# Saving work 19 counter value 200
# Saving work 15 counter value 200
# Saving work 0 counter value 200
# Saving work 18 counter value 200
# Saving work 7 counter value 200
# Saving work 16 counter value 250
# Saving work 22 counter value 250
# Saving work 3 counter value 200
# Saving work 6 counter value 200
# Saving work 14 counter value 200
# Saving work 25 counter value 200
# Saving work 13 counter value 250
# Saving work 26 counter value 200
# Saving work 11 counter value 250
# Saving work 4 counter value 250
# Saving work 1 counter value 250
# Saving work 24 counter value 250
# Saving work 2 counter value 250
# Saving work 20 counter value 250
# Saving work 9 counter value 250
# Saving work 5 counter value 250
# Saving work 17 counter value 250
# Saving work 10 counter value 250
# Saving work 8 counter value 250
# Saving work 12 counter value 250
# Saving work 23 counter value 250
# Saving work 21 counter value 250
# Saving work 18 counter value 250
# Saving work 0 counter value 250
# Saving work 19 counter value 250
# Saving work 15 counter value 250
# Saving work 7 counter value 250
# Saving work 13 counter value 300
# Saving work 16 counter value 300
# Saving work 14 counter value 250
# Saving work 3 counter value 250
# Saving work 22 counter value 300
# Saving work 6 counter value 250
# Saving work 24 counter value 300
# Saving work 11 counter value 300
# Saving work 4 counter value 300
# Saving work 21 counter value 300
# Saving work 26 counter value 250
# Saving work 1 counter value 300
# Saving work 25 counter value 250
# Saving work 10 counter value 300
# Saving work 17 counter value 300
# Saving work 20 counter value 300
# Saving work 2 counter value 300
# Saving work 8 counter value 300
# Saving work 9 counter value 300
# Saving work 23 counter value 300
# Saving work 12 counter value 300
# Saving work 19 counter value 300
# Saving work 18 counter value 300
# Saving work 7 counter value 300
# Saving work 0 counter value 300
# Saving work 15 counter value 300
# Saving work 13 counter value 350
# Saving work 16 counter value 350
# Saving work 14 counter value 300
# Saving work 6 counter value 300
# Saving work 3 counter value 300
# Saving work 22 counter value 350
# Saving work 10 counter value 350
# Saving work 4 counter value 350
# Saving work 5 counter value 300
# Saving work 1 counter value 350
# Saving work 11 counter value 350
# Saving work 24 counter value 350
# Saving work 20 counter value 350
# Saving work 26 counter value 300
# Saving work 17 counter value 350
# Saving work 21 counter value 350
# Saving work 2 counter value 350
# Saving work 7 counter value 350
# Saving work 18 counter value 350
# Saving work 8 counter value 350
# Saving work 19 counter value 350
# Saving work 9 counter value 350
# Saving work 25 counter value 300
# Saving work 3 counter value 350
# Saving work 12 counter value 350
# Saving work 0 counter value 350
# Saving work 13 counter value 400
# Saving work 16 counter value 400
# Saving work 15 counter value 350
# Saving work 23 counter value 350
# Saving work 22 counter value 400
# Saving work 14 counter value 350
# Saving work 6 counter value 350
# Saving work 4 counter value 400
# Saving work 11 counter value 400
# Saving work 5 counter value 350
# Saving work 17 counter value 400
# Saving work 20 counter value 400
# Saving work 7 counter value 400
# Saving work 10 counter value 400
# Saving work 26 counter value 350
# Saving work 1 counter value 400
# Saving work 24 counter value 400
# Saving work 12 counter value 400
# Saving work 8 counter value 400
# Saving work 9 counter value 400
# Saving work 18 counter value 400
# Saving work 19 counter value 400
# Saving work 2 counter value 400
# Saving work 3 counter value 400
# Saving work 21 counter value 400
# Saving work 23 counter value 400
# Saving work 13 counter value 450
# Saving work 16 counter value 450
# Saving work 0 counter value 400
# Saving work 15 counter value 400
# Saving work 22 counter value 450
# Saving work 4 counter value 450
# Saving work 25 counter value 350
# Saving work 6 counter value 400
# Saving work 14 counter value 400
# Saving work 11 counter value 450
# Saving work 20 counter value 450
# Saving work 1 counter value 450
# Saving work 5 counter value 400
# Saving work 10 counter value 450
# Saving work 12 counter value 450
# Saving work 17 counter value 450
# Saving work 24 counter value 450
# Saving work 7 counter value 450
# Saving work 26 counter value 400
# Saving work 19 counter value 450
# Saving work 21 counter value 450
# Saving work 9 counter value 450
# Saving work 18 counter value 450
# Saving work 2 counter value 450
# Saving work 15 counter value 450
# Saving work 8 counter value 450
# Saving work 3 counter value 450
# Saving work 23 counter value 450
# Saving work 0 counter value 450
# Traceback (most recent call last):
#   File "<ipython-input-95-a07ebce81d51>", line 28, in create_classif_data
#     s, r = genetic_best_sum(t, a, 6)
#   File "<ipython-input-84-5ca35ba0b0b7>", line 39, in genetic_best_sum
#     best_summary = offsprings[best_idx[-1]]
# IndexError: index -1 is out of bounds for axis 0 with size 0
# Saving work 13 counter value 500
# Saving work 4 counter value 500
# Saving work 16 counter value 500
# Saving work 22 counter value 500
# Saving work 25 counter value 400
# Saving work 14 counter value 450
# Saving work 11 counter value 500
# Saving work 6 counter value 450
# Saving work 1 counter value 500
# Saving work 20 counter value 500
# Saving work 9 counter value 500
# Saving work 17 counter value 500
# Saving work 10 counter value 500
# Saving work 18 counter value 500
# Saving work 21 counter value 500
# Saving work 24 counter value 500
# Saving work 5 counter value 450
# Saving work 12 counter value 500
# Saving work 3 counter value 500
# Saving work 26 counter value 450
# Saving work 8 counter value 500
# Saving work 19 counter value 500
# Saving work 7 counter value 500
# Saving work 15 counter value 500
# Saving work 23 counter value 500
# Saving work 13 counter value 550
# Saving work 0 counter value 500
# Saving work 16 counter value 550
# Saving work 11 counter value 550
# Saving work 6 counter value 500
# Saving work 4 counter value 550
# Saving work 22 counter value 550
# Saving work 25 counter value 450
# Saving work 2 counter value 500
# Saving work 14 counter value 500
# Saving work 17 counter value 550
# Saving work 18 counter value 550
# Saving work 1 counter value 550
# Saving work 10 counter value 550
# Saving work 12 counter value 550
# Saving work 20 counter value 550
# Saving work 24 counter value 550
# Saving work 3 counter value 550
# Saving work 5 counter value 500
# Saving work 21 counter value 550
# Saving work 9 counter value 550
# Saving work 8 counter value 550
# Saving work 23 counter value 550
# Saving work 16 counter value 600
# Saving work 19 counter value 550
# Saving work 15 counter value 550
# Saving work 26 counter value 500
# Saving work 7 counter value 550
# Saving work 13 counter value 600
# Saving work 0 counter value 550
# Saving work 6 counter value 550
# Saving work 25 counter value 500
# Saving work 4 counter value 600
# Saving work 11 counter value 600
# Saving work 18 counter value 600
# Saving work 22 counter value 600
# Saving work 17 counter value 600
# Saving work 20 counter value 600
# Saving work 1 counter value 600
# Saving work 14 counter value 550
# Saving work 10 counter value 600
# Saving work 2 counter value 550
# Saving work 12 counter value 600
# Process #11 finished
# Saving work 24 counter value 600
# Saving work 21 counter value 600
# Process #18 finished
# Process #16 finished
# Process #4 finished
# Process #13 finished
# Saving work 5 counter value 550
# Saving work 3 counter value 600
# Saving work 9 counter value 600
# Process #20 finished
# Saving work 8 counter value 600
# Saving work 23 counter value 600
# Process #10 finished
# Saving work 19 counter value 600
# Process #22 finished
# Saving work 0 counter value 600
# Saving work 7 counter value 600
# Saving work 26 counter value 550
# Process #21 finished
# Process #24 finished
# Saving work 6 counter value 600
# Saving work 15 counter value 600
# Process #1 finished
# Saving work 25 counter value 550
# Process #12 finished
# Saving work 14 counter value 600
# Saving work 2 counter value 600
# Process #3 finished
# Process #23 finished
# Process #17 finished
# Process #19 finished
# Process #8 finished
# Process #9 finished
# Process #7 finished
# Process #15 finished
# Process #2 finished
# Saving work 5 counter value 600
# Process #14 finished
# Process #6 finished
# Process #0 finished
# Saving work 26 counter value 600
# Saving work 25 counter value 600
# Process #5 finished
# Process #26 finished
# Process #25 finished
# 4

# %% [markdown]
# ### Put it all together

# %%
#y = []
#x = []
br = []
ar_id = []
best_sums = []

for i in tqdm(range(27)):
    #x_n = load_obj('./_gen_tmp/X_gen'+str(i))
    #y_n = load_obj('./_gen_tmp/Y_gen'+str(i))
    br_n = load_obj('./_gen_tmp/best_rouges_gen'+str(i))
    ar_id_n = load_obj('./_gen_tmp/Art_ID_gen'+str(i))
    best_sums_n = load_obj('./_gen_tmp/best_sum_gen'+str(i))
    
    print(i, len(br_n), len(ar_id_n), len(best_sums_n))#len(x_n), len(y_n), len(x_n)-len(y_n), 
    
    #x = x + x_n
    #y = y + y_n
    br = br + br_n
    ar_id = ar_id + ar_id_n
    best_sums = best_sums +best_sums_n
    
print(len(br), len(ar_id), len(x)-len(y), len(best_sums))#len(x),len(y),
# Out:
#   0%|          | 0/27 [00:00<?, ?it/s]
# 0 632 632 632
# 1 631 631 631
# 2 631 631 631
# 3 631 631 631
# 4 631 631 631
# 5 631 631 631
# 6 631 631 631
# 7 631 631 631
# 8 631 631 631
# 9 631 631 631
# 10 631 631 631
# 11 631 631 631
# 12 631 631 631
# 13 631 631 631
# 14 631 631 631
# 15 631 631 631
# 16 631 631 631
# 17 631 631 631
# 18 631 631 631
# 19 631 631 631
# 20 631 631 631
# 21 631 631 631
# 22 631 631 631
# 23 631 631 631
# 24 631 631 631
# 25 631 631 631
# 26 631 631 631
# 17038 17038 0 17038

# %%
ds_gen = pd.DataFrame()
ds_gen['best_summary_gen'] = best_sums#[[s for s, l in zip(art_sents, labels) if l == 1] for art_sents, labels in zip(x, y)]
ds_gen['best_rouge1_gen'] = [r[0] for r in br]
ds_gen['best_rouge2_gen'] = [r[1] for r in br]
ds_gen['article_id'] = [ids[0] for ids in ar_id]
ds_gen.head()
# Out:
#                                     best_summary_gen  best_rouge1_gen  \
# 0  [once discovered , the study of a particular s...         0.565217
# 1  [, the process of flux emergence occurs on ver...         0.598753
# 2  [+ the purpose of this paper is then to develo...         0.528455
# 3  [power - law behavior is observed on a large -...         0.623656
# 4  [we understand the closure of the set of expan...         0.599496
#
#    best_rouge2_gen       article_id
# 0         0.157718  astro-ph0202198
# 1         0.288100        0905.2691
# 2         0.130612        1305.7010
# 3         0.354391        1402.0371
# 4         0.222785       1701.00774

# %%
ds_merged = load_obj('ds_merged')
ds_merged.shape
# Out:
# (17039, 27)

# %%
#merge two dataframes
ds_merged = pd.merge(ds_merged, ds_gen, on='article_id')
ds_merged.head()
# Out:
#         article_id                                       article_text  \
# 0  astro-ph0202198  [the study of supernovae ( sne ) has greatly a...
# 1        0905.2691  [it is believed that solar magnetic fields are...
# 2        1305.7010  [the origin - destination ( od ) matrix is imp...
# 3        1402.0371  [multiscale dynamics is present in many phenom...
# 4       1701.00774  [the @xmath3-transformation has been extensive...
#
#                                        abstract_text  \
# 0  [large numbers of supernovae ( sne ) have been...
# 1  [we investigate the emergence of magnetic flux...
# 2  [the estimation of the number of passengers wi...
# 3  [the classical structure - function ( sf ) met...
# 4  [given a real number @xmath0 , we study the as...
#
#                                        section_names  \
# 0  [introduction, method, results, future prospec...
# 1  [introduction, observations and data reduction...
# 2  [introduction, the passenger model, the observ...
# 3  [introduction, detrending analysis and detrend...
# 4  [introduction, coded negative beta-shift, lap ...
#
#                                             sections  len_text  len_abstract  \
# 0  [[the study of supernovae ( sne ) has greatly ...       341            12
# 1  [[it is believed that solar magnetic fields ar...       329            11
# 2  [[the origin - destination ( od ) matrix is im...       225            10
# 3  [[multiscale dynamics is present in many pheno...       216            15
# 4  [[the @xmath3-transformation has been extensiv...       353            11
#
#    sent_ext  word_ext  word_inf  ...  \
# 0  0.000000  0.897436  0.076004  ...
# 1  0.000000  0.884892  0.073258  ...
# 2  0.000000  0.740157  0.074367  ...
# 3  0.066667  0.949045  0.171659  ...
# 4  0.000000  0.867925  0.059547  ...
#
#                           best_summary_vns_initgreed  \
# 0  [once discovered , the study of a particular s...
# 1  [they move upward and emerge into the solar at...
# 2  [a particular application of the od matrix est...
# 3  [a detrended structure - function ( dsf ) meth...
# 4  [thus , the previous proposition allows us to ...
#
#    best_rouge1_vns_initgreed best_rouge2_vns_initgreed len_sum_vns  \
# 0                   0.484935                  0.146763          15
# 1                   0.629482                  0.296000          14
# 2                   0.474187                  0.119002          19
# 3                   0.767442                  0.563333          16
# 4                   0.541176                  0.236407          14
#
#    len_sum_wih  len_sum_vot len_sum_vns_init_greed  \
# 0            5           15                      5
# 1            9            9                      9
# 2            4           19                     14
# 3           11           11                     11
# 4            4            4                      4
#
#                                     best_summary_gen  best_rouge1_gen  \
# 0  [once discovered , the study of a particular s...         0.565217
# 1  [, the process of flux emergence occurs on ver...         0.598753
# 2  [+ the purpose of this paper is then to develo...         0.528455
# 3  [power - law behavior is observed on a large -...         0.623656
# 4  [we understand the closure of the set of expan...         0.599496
#
#    best_rouge2_gen
# 0         0.157718
# 1         0.288100
# 2         0.130612
# 3         0.354391
# 4         0.222785
#
# [5 rows x 30 columns]

# %%
#ds_merged['len_sum_vns'] = [len(a) for a in ds_merged['best_summary_vns'].values]
#ds_merged['len_sum_wih'] = [len(a) for a in ds_merged['best_summary_wih'].values]
#ds_merged['len_sum_vot'] = [len(a) for a in ds_merged['voted_summary'].values]
ds_merged['len_sum_gen'] = [len(a) for a in ds_merged['best_summary_gen'].values]

# %%
save_obj(ds_merged, 'ds_merged')

# %%
ds_merged.describe()
# Out:
#            len_text  len_abstract      sent_ext      word_ext      word_inf  \
# count  17038.000000  17038.000000  17038.000000  17038.000000  17038.000000
# mean     263.444360     11.768576      0.009705      0.859045      0.099746
# std      102.651972      2.141314      0.043253      0.093133      0.029403
# min      100.000000     10.000000      0.000000      0.112000      0.019078
# 25%      179.000000     10.000000      0.000000      0.826087      0.078901
# 50%      252.000000     11.000000      0.000000      0.880000      0.095601
# 75%      338.000000     13.000000      0.000000      0.918750      0.116252
# max      500.000000     20.000000      0.900000      1.000000      0.290541
#
#        best_rouge1_wih  best_rouge2_wih  best_rouge1_vns  best_rouge2_vns  \
# count     17038.000000     17038.000000     17038.000000     17038.000000
# mean          0.552754         0.233332         0.552338         0.211357
# std           0.083730         0.103396         0.066306         0.079049
# min           0.041428         0.009938         0.074289         0.011204
# 25%           0.507865         0.164921         0.520117         0.158035
# 50%           0.552147         0.212286         0.555740         0.199250
# 75%           0.599237         0.275685         0.590308         0.251441
# max           0.969005         0.932897         0.837662         0.778502
#
#            voted_r1      voted_r2  best_rouge1_vns_initgreed  \
# count  17038.000000  17038.000000               17038.000000
# mean       0.572324      0.238570                   0.578069
# std        0.074507      0.102615                   0.076625
# min        0.094595      0.020498                   0.094595
# 25%        0.533890      0.171059                   0.537634
# 50%        0.571093      0.217921                   0.578066
# 75%        0.610541      0.281561                   0.619909
# max        0.969005      0.932897                   0.969005
#
#        best_rouge2_vns_initgreed   len_sum_vns   len_sum_wih   len_sum_vot  \
# count               17038.000000  17038.000000  17038.000000  17038.000000
# mean                    0.245358     15.334312      7.012678     11.303850
# std                     0.103586      4.919018      2.913752      5.394884
# min                     0.017766     11.000000      1.000000      3.000000
# 25%                     0.177564     13.000000      5.000000      7.000000
# 50%                     0.224919     14.000000      7.000000     12.000000
# 75%                     0.288761     16.000000      8.000000     14.000000
# max                     0.954315     89.000000     41.000000     89.000000
#
#        len_sum_vns_init_greed  best_rouge1_gen  best_rouge2_gen   len_sum_gen
# count            17038.000000     17038.000000     17038.000000  17038.000000
# mean                 9.545252         0.581534         0.238658     11.768576
# std                  5.052838         0.073449         0.091883      2.141314
# min                  3.000000         0.085583         0.006299     10.000000
# 25%                  6.000000         0.546426         0.177320     10.000000
# 50%                  8.000000         0.587440         0.225108     11.000000
# 75%                 13.000000         0.625225         0.285022     13.000000
# max                 86.000000         0.861244         0.834771     20.000000

# %%
ds_merged.describe().to_excel('VNS_init_Greedy.xlsx', sheet_name='VNS_init_Greedy')

# %%
ds_merged['best_rouge1_vns'].plot.hist(figsize=(20, 10), alpha=0.5)
ds_merged['best_rouge1_wih'].plot.hist(figsize=(20, 10), alpha=0.5)
ds_merged['voted_r1'].plot.hist(figsize=(20, 10), alpha=0.5)
ds_merged['best_rouge1_vns_initgreed'].plot.hist(figsize=(20, 10), alpha=0.5)
ds_merged['best_rouge2_vns'].plot.hist(figsize=(20, 10), alpha=0.5)
ds_merged['best_rouge2_wih'].plot.hist(figsize=(20, 10), alpha=0.5)
ds_merged['voted_r2'].plot.hist(figsize=(20, 10), alpha=0.5)
ds_merged['best_rouge2_vns_initgreed'].plot.hist(figsize=(20, 10), alpha=0.5)
plt.legend(['VNS ROUGE-1', 'Greedy ROUGE-1', 'VOTED ROUGE-1', 'VNS initgreed ROUGE-1', 'VNS ROUGE-2', 'Greedy ROUGE-2', 'VOTED ROUGE-2', 'VNS initgreed ROUGE-2'], fontsize='xx-large')
plt.ylabel('Frequency', fontsize=18)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# Out:
# (array([    0.,  2000.,  4000.,  6000.,  8000., 10000.]),
#  <a list of 6 Text yticklabel objects>)
